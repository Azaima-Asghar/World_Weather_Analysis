# %%
# Import the dependencies.

import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.

data_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")
data_df.head()
# Out:
#    Unnamed: 0        City Country  Max Temp Current Description    Lat  \
# 0           1     Rikitea      PF     76.37       broken clouds -23.12
# 1          10  Butaritari      KI     82.85     overcast clouds   3.07
# 2          11      Salina      US     75.20           clear sky  38.84
# 3          12  Santa Rosa      PH     88.00          few clouds  14.31
# 4          15  Vila Velha      BR     78.80       broken clouds -20.33
#
#       Lng                           Hotel Name
# 0 -134.97                       Pension Maro'i
# 1  172.79                   Isles Sunset Lodge
# 2  -97.61  Holiday Inn Express & Suites Salina
# 3  121.11           Erlyn’s Sta Rosa City Home
# 4  -40.29                 Hotel Vitória Palace
